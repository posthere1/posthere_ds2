# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
# !pip install xgboost

# %%
from xgboost import XGBRegressor

# %%
# !unxz embeddings.pq.xz

# %%
# !pip install category_encoders
# Out:
# ...
#      |████████████████████████████████| 81kB 2.1MB/s
# ...

# %%
df = pd.read_parquet("embeddings.pq")

# %%
from category_encoders import OneHotEncoder

# %%
from sklearn.decomposition import PCA

# %%
ce = OneHotEncoder(use_cat_names=True)

# %%
subreddit_oh = ce.fit_transform(df[['subreddit']], )

# %%
subreddit_oh.head(1)
# Out:
#    subreddit_r/AskReddit  ...  subreddit_r/pokemongo
# 0                      1  ...                      0
#
# [1 rows x 72 columns]

# %%
ce.mapping
# Out:
# [{'col': 'subreddit',
#   'mapping':      subreddit_1  subreddit_2  ...  subreddit_71  subreddit_72
#    1             1            0  ...             0             0
#    2             0            1  ...             0             0
#    3             0            0  ...             0             0
#    4             0            0  ...             0             0
#    5             0            0  ...             0             0
#   ..           ...          ...  ...           ...           ...
#    70            0            0  ...             0             0
#    71            0            0  ...             1             0
#    72            0            0  ...             0             1
#   -1             0            0  ...             0             0
#   -2             0            0  ...             0             0
#
#   [74 rows x 72 columns]}]

# %%
title_encodings = df['title_embeddings'].apply(pd.Series)

# %%
text_encodings = df['text_embeddings'].apply(pd.Series)

# %%
pca_title = PCA(32)

# %%
title_encodings_pca = pd.DataFrame(pca_title.fit_transform(title_encodings))

# %%
pca_text = PCA(32)
text_embeddings_pca = pd.DataFrame(pca_text.fit_transform(text_encodings))

# %%
train = pd.concat([title_encodings_pca, text_embeddings_pca], axis=1)

# %%
train
# Out:
#               0         1         2   ...        29        30        31
# 0      -5.400881 -0.512331 -0.879891  ...  0.019452 -0.010400 -0.008974
# 1      -5.346913 -0.282868 -0.085791  ...  0.019452 -0.010400 -0.008974
# 2      -4.665344 -1.363176  0.291401  ...  0.019452 -0.010400 -0.008974
# 3      13.347385 -0.573864 -0.182073  ... -0.064686  0.247893  0.824603
# 4      -4.948433 -0.711959 -0.047250  ...  0.019452 -0.010400 -0.008974
# ...          ...       ...       ...  ...       ...       ...       ...
# 18572   9.996374 -0.626319  1.064395  ...  0.119416  0.103710 -0.277484
# 18573  -5.251443 -0.890901 -0.348335  ... -0.106329  0.060840  0.545784
# 18574  -5.783082 -0.788416 -0.636627  ...  0.019452 -0.010400 -0.008974
# 18575  -5.381359 -0.219882 -0.409660  ... -0.337942  0.258182 -0.113246
# 18576  -4.646720 -1.020218  0.025050  ... -0.063484  0.236697  0.123945
#
# [18577 rows x 64 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(train, df['up_votes'])

# %%
train_set = [X_train, y_train]
test_set = (X_test, y_test)

# %%
# Out:
#               0         1         2   ...        29        30        31
# 353    -4.713323  0.144705  0.253260  ...  0.019452 -0.010400 -0.008974
# 8690   -5.643509 -0.294579 -1.161319  ... -0.053671 -0.160569  0.273410
# 10700  13.487591 -1.451065 -0.862363  ... -0.111510 -0.127551  0.767378
# 718    -5.124892 -0.853681 -0.423028  ...  0.019452 -0.010400 -0.008974
# 2020   -5.230646 -1.105649 -0.228122  ...  0.019452 -0.010400 -0.008974
# ...          ...       ...       ...  ...       ...       ...       ...
# 17140  -5.755004 -0.238607 -0.837437  ...  0.003705 -0.397978 -0.539217
# 1009   -4.466127  0.583503  0.586349  ... -0.406684  0.026447 -0.563172
# 15693  -5.310928 -0.795011 -0.709526  ...  0.340149  0.007014  0.181593
# 11607  12.574090  1.199577  0.364375  ...  0.440320  0.875047  0.238441
# 1735   14.244317 -0.511483 -0.158446  ...  0.019452 -0.010400 -0.008974
#
# [13932 rows x 64 columns]

# %%
model = sk_model()

# %%
model.fit(*train_set)
# Out:
# LGBMRegressor(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#               importance_type='split', learning_rate=0.1, max_depth=-1,
#               min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#               n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#               random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#               subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(y_test, model.predict(X_test))
# Out:
# 6531.803241724411

# %%
train = pd.concat([subreddit_oh, title_encodings_pca, text_embeddings_pca], axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(train, df['up_votes'])
train_set = [X_train, y_train]
test_set = (X_test, y_test)

# %%
model = sk_model()
model.fit(*train_set)
mean_absolute_error(y_test, model.predict(X_test))
# Out:
# 6482.936598150536

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test, model.predict(X_test), squared=False)
# Out:
# 11827.330585946132

# %%
# !pip install basilica

# %%
import basilica

# %%
model.n_features_
# Out:
# 136

# %%
X_train
# Out:
#        subreddit_r/AskReddit  subreddit_r/gaming  ...        30        31
# 1120                       0                   0  ...  0.602008 -0.654248
# 13928                      0                   0  ... -0.058200  0.226496
# 16150                      0                   0  ... -0.017525 -0.280625
# 57                         1                   0  ... -0.010400 -0.008974
# 1954                       0                   0  ... -0.010400 -0.008974
# ...                      ...                 ...  ...       ...       ...
# 15216                      0                   0  ...  0.142762  0.040246
# 4478                       0                   0  ... -0.617561  0.016911
# 16161                      0                   0  ...  0.587263  0.736407
# 3012                       0                   0  ...  0.122635 -0.166907
# 2284                       0                   0  ... -0.180926 -0.250125
#
# [13932 rows x 136 columns]

# %%
import pickle

# %%
from xgboost import XGBRegressor

# %%
# !pip install basilica
# Out:
# ...
#   Created wheel for basilica: filename=basilica-0.2.8-cp36-none-any.whl size=4711 sha256=3e3a96c35dd7b1d81ba7319020c2fe59f36a9f5ed4c2e41933355894b32c85ec
#   Stored in directory: /root/.cache/pip/wheels/31/18/9f/46f6face8baf98e31b52bf91a0d76930ec76860f9e9211104d
# Successfully built basilica
# ...

# %%
with open("model.pickle", "rb") as f:
    model = pickle.load(f)
# Out:
# Exception ignored in: <bound method Booster.__del__ of <xgboost.core.Booster object at 0x7f7182b92eb8>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/xgboost/core.py", line 957, in __del__
#     if self.handle is not None:
# AttributeError: 'Booster' object has no attribute 'handle'
# /usr/local/lib/python3.6/dist-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator LassoCV from version 0.22.2 when using version 0.22.2.post1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator Pipeline from version 0.22.2 when using version 0.22.2.post1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)

# %%
class upvote_predictor:

    def __init__(self, model,):
        self.model = model
        import basilica
        import pandas as pd
        import category_encoders

    def prepare_string(self, string, pca):
        embedding = None
        with basilica.Connection('370a60d1-2938-b1bf-d813-0cb6954f5a0e') as c:
            embedding = c.embed_sentence(
                string,
                model='reddit',
                timeout=120
                )
        df = pd.Series(embedding)
        df = pd.DataFrame(df).T
        df = pd.Series(df)
        df = pd.DataFrame(df).T
        return df


    def predict(self, title, text, subreddit):
        title = self.prepare_string(title, self.title_pca)
        text = self.prepare_string(text, self.text_pca)
        embeddings = pd.concat([title, text], axis = 1)
        embeddings.columns = [i for i in range(1536)]
        
        df = pd.concat([subreddit, embeddings], axis=1)
        return int(self.model.predict(df)[0])

# %%
predictor = upvote_predictor(model)

# %%
predictor.predict("This is a dumb title", "Text here", "r/AskReddit")
# Out:
# 108139

# %%
from pathlib import Path

# %%
path = Path("./upvote_predictor.pickle")

# %%
import pickle

# %%
with open(path, 'wb+') as f:
    pickle.dump(predictor, f)
